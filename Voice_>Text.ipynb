# %% [markdown]
# <a href="https://colab.research.google.com/github/Sathvikabanavath/GenAI-Tasks/blob/main/Voice_%3EText.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install SpeechRecognition pydub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 56.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-00973ad0-e246-4c6a-86d8-192097af4877" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-00973ad0-e246-4c6a-86d8-192097af4877">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import speech_recognition as sr
from pydub import AudioSegment
import os
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):

# %%
# Get uploaded file name
audio_file = list(uploaded.keys())[0]
print("Uploaded file:", audio_file)
# Out:
# Uploaded file: 8 May, 9.03 pm_.m4a

# %%
# Convert to WAV if needed
if not audio_file.endswith(".wav"):
    sound = AudioSegment.from_file(audio_file)
    sound.export("converted.wav", format="wav")
    audio_file = "converted.wav"

# %%
recognizer = sr.Recognizer()
with sr.AudioFile(audio_file) as source:
    audio = recognizer.record(source)
try:
    text = recognizer.recognize_google(audio, language="hi-IN")
    print("Transcribed Text:")
    print(text)
except sr.UnknownValueError:
    print("Could not understand the audio")

except sr.RequestError as e:
    print("API Error:", e)
# Out:
# Transcribed Text:
# ही आई एम सात्विका
