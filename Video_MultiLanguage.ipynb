# %% [markdown]
# <a href="https://colab.research.google.com/github/Sathvikabanavath/GenAI-Tasks/blob/main/Video_MultiLanguage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q yt-dlp openai-whisper transformers sentencepiece
# !apt-get install -y ffmpeg

# %%
import whisper
import subprocess
from transformers import pipeline

# %%
youtube_url = "https://youtu.be/EDb37y_MhRw?si=GZyo3Np2v1TVpYth"

# %%
audio_file = "yt_audio.wav"

subprocess.run([
    "yt-dlp",
    "-x", "--audio-format", "wav",
    "-o", audio_file,
    youtube_url
])

print("Audio extracted from YouTube video")

# %%
clean_audio = "audio_clean.wav"

subprocess.run([
    "ffmpeg", "-y",
    "-i", audio_file,
    "-ac", "1",
    "-ar", "16000",
    clean_audio
])

print("Audio re‑encoded for Whisper")

# %%
whisper_model = whisper.load_model("base")

result = whisper_model.transcribe(clean_audio)
transcribed_text = result["text"]

print("\n Transcribed Text:\n")
print(transcribed_text)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")

tokenizer.src_lang = "eng_Latn"

inputs = tokenizer(
    transcribed_text,
    return_tensors="pt",
    truncation=True,
    max_length=512
)

# Hindi language code
forced_bos_token_id_hi = tokenizer.convert_tokens_to_ids("hin_Deva")

translated_tokens_hi = model.generate(
    **inputs,
    forced_bos_token_id=forced_bos_token_id_hi,
    max_length=600
)

hindi_full_translation = tokenizer.decode(
    translated_tokens_hi[0],
    skip_special_tokens=True
)

print("🇮🇳 Hindi Translation (Full Audio):\n")
print(hindi_full_translation)

# %%
forced_bos_token_id_te = tokenizer.convert_tokens_to_ids("tel_Telu")

translated_tokens_te = model.generate(
    **inputs,
    forced_bos_token_id=forced_bos_token_id_te,
    max_length=600
)

telugu_full_translation = tokenizer.decode(
    translated_tokens_te[0],
    skip_special_tokens=True
)

print("🇮🇳 Telugu Translation (Full Audio):\n")
print(telugu_full_translation)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
model_name = "facebook/nllb-200-distilled-600M"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

tokenizer.src_lang = "eng_Latn"

# %%
print("\nSelect a language to translate the audio text:\n")
print("1. Hindi")
print("2. Telugu")
print("3. Tamil")
print("4. French")
print("5. German")
print("6. Spanish")
print("7. Korean")

choice = input("\nEnter your choice (1–7): ")

# %%
language_map = {
    "1": "hin_Deva",
    "hindi": "hin_Deva",
    "2": "tel_Telu",
    "telugu": "tel_Telu",
    "3": "tam_Taml",
    "tamil": "tam_Taml",
    "4": "fra_Latn",
    "french": "fra_Latn",
    "5": "deu_Latn",
    "german": "deu_Latn",
    "6": "spa_Latn",
    "spanish": "spa_Latn",
    "7": "kor_Hang",
    "korean": "kor_Hang"
}

processed_choice = choice.lower()

if processed_choice not in language_map:
    raise ValueError("Invalid choice selected")

target_language = language_map[processed_choice]

# %%
inputs = tokenizer(
    transcribed_text,
    return_tensors="pt",
    truncation=True,
    max_length=512
)

forced_bos_token_id = tokenizer.convert_tokens_to_ids(target_language)

translated_tokens = model.generate(
    **inputs,
    forced_bos_token_id=forced_bos_token_id,
    max_length=600
)

translated_text = tokenizer.decode(
    translated_tokens[0],
    skip_special_tokens=True
)

print("\n Translated Text:\n")
print(translated_text)
